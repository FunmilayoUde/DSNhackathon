# %% [markdown]
# #### Connection of The School Database to the NOtebook Environment

# %%
#!pip install psycopg2-binary

# %%
import psycopg2
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# Define PostgreSQL database connection parameters
connection = psycopg2.connect(
    host="localhost",         # e.g., "localhost"
    database="team_innovate", # Database name
    user="postgres",         # Username
    password="242129", # Password
    port="5432"               # Default PostgreSQL port
)

# Create a query to fetch the data
query = "SELECT * FROM Bestbrain_school.students"

# Load the data into a pandas DataFrame
students = pd.read_sql_query(query, connection)

# Close the connection
connection.close()

# Display the first few rows of the data
students.head()
# Out:
#    student_id first_name last_name  gender date_of_birth admission_date  \
# 0       93810    Adebayo   Kehinde    Male    1984-04-15     2017-04-23
# 1       24592     Abiola     Tunde    Male    1985-12-23     2017-01-09
# 2       13278      Kunle  Akinyemi  Female    1985-06-29     2018-07-16
# 3       46048     Adeola    Mayowa    Male    1984-11-05     2020-03-05
# 4       42098      Segun   Adeyemi    Male    1989-01-21     2019-09-05
#
#   class_section class_level      religion   tribe state_of_origin  \
# 0          B            SS1  Christianity  Yoruba            Ogun
# 1          C            SS2         Islam  Yoruba             Oyo
# 2          A            SS1  Christianity  Yoruba             Oyo
# 3          C            SS1         Islam  Yoruba            Ondo
# 4          D            SS1         Islam  Yoruba            Ogun
#
#      parent_name               parent_occupation  parent_income  \
# 0   Mary Kehinde                Ambulance person       438159.0
# ...

# %%
# Define PostgreSQL database connection parameters
connection = psycopg2.connect(
    host="localhost",         # e.g., "localhost"
    database="team_innovate", # Database name
    user="postgres",         # Username
    password="242129", # Password
    port="5432"               # Default PostgreSQL port
)

# Create a query to fetch the data
query = "SELECT * FROM Bestbrain_school.activities"

# Load the data into a pandas DataFrame
activities = pd.read_sql_query(query, connection)

# Close the connection
connection.close()

# Display the first few rows of the data
activities.head()
# Out:
#    activity_id  student_id             activity_type activity_category  \
# 0       407269       93810         Traditional Dance          Cultural
# 1       156962       93810                     Chess            Sports
# 2       647155       93810                  Scrabble            Sports
# 3       531106       24592  Mathematics Competitions          Academic
# 4       768470       24592          Quiz Competition   Extracurricular
#
#   frequency_of_participation  duration_per_session_hours  \
# 0                    Monthly                        2.38
# 1                      Daily                        1.38
# 2                  Bi-weekly                        2.11
# 3                  Bi-weekly                        2.46
# 4                      Daily                        1.35
#
#   impact_on_performance teacher_supervisor  parental_support
# 0               Neutral        Angel Rojas             False
# 1              Negative        Raymond Roy             False
# ...

# %%
# Define PostgreSQL database connection parameters
connection = psycopg2.connect(
    host="localhost",         # e.g., "localhost"
    database="team_innovate", # Database name
    user="postgres",         # Username
    password="242129", # Password
    port="5432"               # Default PostgreSQL port
)

# Create a query to fetch the data
query = "SELECT * FROM Bestbrain_school.teachers"

# Load the data into a pandas DataFrame
teachers = pd.read_sql_query(query, connection)

# Close the connection
connection.close()

# Display the first few rows of the data
teachers.head()
# Out:
#    teacher_id  student_id marital_status education_level  gender  age  \
# 0        8950       51681         Single             PhD    Male   35
# 1        7954       18834        Widowed            M.Ed    Male   47
# 2        3336       81511         Single            M.Ed    Male   33
# 3        4454       30056         Single            M.Ed  Female   28
# 4        9593       49384         Single             NCE    Male   27
#
#   subject_taught                   degree_own parental_status  \
# 0       Commerce       B.A. Religious Studies              No
# 1      Education              B.Sc. Economics              No
# 2            CRS   B.Sc. Financial Accounting             Yes
# 3      Fine Arts                B.Sc. Physics             Yes
# 4        English  B.Sc. Environmental Science              No
#
#   teacher_training  distance_from_home_to_school_km disability health_issue  \
# 0          Trained                            18.56       None         None
# ...

# %%
# Define PostgreSQL database connection parameters
connection = psycopg2.connect(
    host="localhost",         # e.g., "localhost"
    database="team_innovate", # Database name
    user="postgres",         # Username
    password="242129", # Password
    port="5432"               # Default PostgreSQL port
)

# Create a query to fetch the data
query = "SELECT * FROM Bestbrain_school.schooldata"

# Load the data into a pandas DataFrame
school = pd.read_sql_query(query, connection)

# Close the connection
connection.close()

# Display the first few rows of the data
school.head()
# Out:
#    student_id  teacher_student_ratio  average_teacher_experience_years  \
# 0       93810               21.85508                                 5
# 1       24592               21.85508                                13
# 2       13278               21.85508                                14
# 3       46048               21.85508                                15
# 4       42098               21.85508                                16
#
#    average_class_size  scholarship_per_student  \
# 0                  24                    12984
# 1                  24                    23862
# 2                  24                    10914
# 3                  24                    14890
# 4                  24                    24956
#
#   school_extracurricular_activities  parental_involvement_score  \
# 0                              Arts                    6.225391
# 1                              Arts                    9.678251
# ...

# %%
#students.to_csv('students.csv')
#teachers.to_csv('teachers.csv')
#activities.to_csv('activities.csv')
#school.to_csv('school.csv')
